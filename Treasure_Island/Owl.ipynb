# %%
print(''' 
*******************************************************************************
*******************************************************************************
Pulsatrix perspicillata   ,''    ''.
                         / `-.  .-' \
                        /( (O))((O) )
                       /'-..-'/\`-..|
                     ,'\   `-.\/.--'|
                   ,' ( \           |
                 ,'( (   `._        |
                /( (  ( ( | `-._ _,-;
               /( (  ( ( (|     '  ;
              / ((  (    /        /
             //         /        /
             //  / /  ,'        /
            // /    ,'         /
            //  / ,'          ;
            //_,-'          ;
            // /,,,,..-))-))\    /|
              /; ; ;\ `.  \  \  / |
             /; ; ; ;\  \.  . \/./
            (; ; ;_,_,\  .: \   /
             `-'-'     | : . |:|
           jrei        |. | : .|
*******************************************************************************
*******************************************************************************
''')
# Out:
#
# *******************************************************************************
# *******************************************************************************
# Pulsatrix perspicillata   ,''    ''.
#                          / `-.  .-'                         /( (O))((O) )
#                        /'-..-'/\`-..|
#                      ,'\   `-.\/.--'|
#                    ,' ( \           |
#                  ,'( (   `._        |
#                 /( (  ( ( | `-._ _,-;
#                /( (  ( ( (|     '  ;
#               / ((  (    /        /
#              //         /        /
#              //  / /  ,'        /
#             // /    ,'         /
#             //  / ,'          ;
#             //_,-'          ;
#             // /,,,,..-))-))\    /|
#               /; ; ;\ `.  \  \  / |
#              /; ; ; ;\  \.  . \/./
#             (; ; ;_,_,\  .: \   /
#              `-'-'     | : . |:|
#            jrei        |. | : .|
# ...
